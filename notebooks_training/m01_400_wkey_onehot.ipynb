# %% [markdown]
# # ML model:
#
# ### One-Hot Encoded Models
#
# ### 400 files
#
# ### with keywords

# %%
# === MODELL SPEICHERN ===
prefix = "onehot_400_wkey"
clf_file = f"prometainfer/models/{prefix}_model.pkl"
p_file = f"prometainfer/models/{prefix}_preprocessor.pkl"
enc_file = f"prometainfer/models/{prefix}_label_encoders.pkl"
train_features = f"prometainfer/models/{prefix}_train_features.csv"
keyword_files = "../data/ML_test/keyword_files/keyword_parsing_results.csv"

# %%
import os
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split, cross_validate, cross_val_score, KFold, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPClassifier
from sklearn.impute import SimpleImputer  # For handling NaNs
import joblib

# %%
import os
import re
import pandas as pd
from pathlib import Path

# === 1. EXTRACT FEATURES FROM OpenMS FILEINFO TXT FILES ===
def extract_features_from_txt(file_path):
    """Extracts features from an OpenMS FileInfo text file."""
    features = {
        "instrument_model": "Not available",
        "organism": "Not available",
        "tissue": "Not available",
        "disease": "Not available",
        "software": "Not available",
        "activation_method": "",
        "experiment_type": "Not available",
        "fraction_identifier": "Not available",
        "quantification_method": "Not available",
        "cleavage_agent": "Not available",
    }

    with open(file_path, "r") as f:
        content = f.readlines()
    
    if not content:
        print("empty file")

    for line in content:
        line = line.strip()

        # Extract retention time range
        if "retention time:" in line:
            match = re.findall(r"([\d\.]+)", line)
            if len(match) == 2:
                features["rt_min"] = float(match[0])
                features["rt_max"] = float(match[1])
        
        # Extract mass-to-charge (m/z) range
        elif "mass-to-charge:" in line:
            match = re.findall(r"([\d\.]+)", line)
            if len(match) == 2:
                features["mz_min"] = float(match[0])
                features["mz_max"] = float(match[1])
        
        # Extract intensity range
        elif "intensity:" in line:
            match = re.findall(r"([\d\.e\+]+)", line)  # Handle scientific notation
            if len(match) == 2:
                features["intensity_min"] = float(match[0])
                features["intensity_max"] = float(match[1])
        
        # Extract precursor charge distribution
        elif "charge" in line and "x" in line:
            match = re.search(r"charge (\d+): (\d+)x", line)
            if match:
                charge, count = int(match.group(1)), int(match.group(2))
                features[f"precursor_charge_{charge}"] = count
        
        # Extract instrument model
        elif "Instrument:" in line:
            if features["instrument_model"] == "Not available":
                if(line.split("Instrument: ")[-1].strip() != "Instrument:"):
                    features["instrument_model"] = line.split("Instrument: ")[-1].strip()
        
        # Extract total number of peaks
        elif "Total number of peaks:" in line:
            match = re.search(r"(\d+)", line)
            if match:
                features["total_peaks"] = int(match.group(0))
        
        # Extract number of spectra
        elif "Number of spectra:" in line:
            match = re.search(r"(\d+)", line)
            if match:
                features["num_spectra"] = int(match.group(0))
        
        # Extract organism, tissue, and disease (if available)
        elif "organism:" in line.lower():
            if line.split(": ")[-1].strip() != 'organism:':
                features["organism"] = line.split(": ")[-1].strip() 
        elif "tissue:" in line.lower():
            features["tissue"] = line.split(": ")[-1].strip()
        elif "disease:" in line.lower():
            features["disease"] = line.split(": ")[-1].strip()
        
        # Extract software information
        elif "software name:" in line.lower():
            if(line.split(": ")[-1].strip() != 'software name:'):
                features["software"] = line.split(": ")[-1].strip()

        elif(features["activation_method"] == 'Not available'):
            features["activation_method"] = line.split(':')[0].split("MS-Level 2 & ")[-1].strip()
        
        # Extract activation method
        elif "activation methods" in line.lower():
            features["activation_method"] = 'Not available'
        
        # Extract experiment type (e.g., bottom-up, top-down)
        elif "experiment type:" in line.lower():
            features["experiment_type"] = line.split(": ")[-1].strip()
        
        # Extract fraction identifier
        elif "fraction identifier:" in line.lower():
            features["fraction_identifier"] = line.split(": ")[-1].strip()
        
        # Extract quantification method
        elif "quantification:" in line.lower():
            features["quantification_method"] = line.split(": ")[-1].strip()
        
        # Extract cleavage agent details
        elif "cleavage agent:" in line.lower():
            features["cleavage_agent"] = line.split(": ")[-1].strip()
    if(features["activation_method"] == ""):
        features["activation_method"] = "Not available"
    return features

# === 2. PROCESS ALL FILEINFO TXT FILES ===
txt_folders = ["../data/ML_test/fileinfo_files"]
data = []

for folder in txt_folders:
    folder_path = Path(folder)
    for txt_file in folder_path.glob("*"):  # Iterate over all files
        features = extract_features_from_txt(txt_file)
        features["Filename"] = str(txt_file).split("/")[-1]+".mzML"#.split('_fileinfo')[0].split('txts/')[-1]  # Convert filename for matching
        data.append(features)

# Convert to DataFrame
features_df = pd.DataFrame(data)
features_df
# Out:
#     instrument_model       organism         tissue        disease  \
# 0      Not available  Not available  Not available  Not available
# 1      Not available  Not available  Not available  Not available
# 2         Q Exactive  Not available  Not available  Not available
# 3    Orbitrap Fusion  Not available  Not available  Not available
# 4      Not available  Not available  Not available  Not available
# ..               ...            ...            ...            ...
# 395    Not available  Not available  Not available  Not available
# 396    Not available  Not available  Not available  Not available
# 397   TripleTOF 6600  Not available  Not available  Not available
# 398    Not available  Not available  Not available  Not available
# 399    Not available  Not available  Not available  Not available
#
#                   software                                  activation_method  \
# 0      Proteome Discoverer  HCID (High-energy collision-induced dissociation)
# 1      Proteome Discoverer  HCID (High-energy collision-induced dissociation)
# 2    ProteoWizard software  HCID (High-energy collision-induced dissociation)
# 3    ProteoWizard software  HCID (High-energy collision-induced dissociation)
# 4    ProteoWizard software  HCID (High-energy collision-induced dissociation)
# ..                     ...                                                ...
# 395    Proteome Discoverer  HCID (High-energy collision-induced dissociation)
# 396    Proteome Discoverer  HCID (High-energy collision-induced dissociation)
# 397  ProteoWizard software  HCID (High-energy collision-induced dissociation)
# 398    Proteome Discoverer  HCID (High-energy collision-induced dissociation)
# 399  ProteoWizard software                                      Not available
#
#     experiment_type fraction_identifier quantification_method cleavage_agent  \
# 0     Not available       Not available         Not available  Not available
# 1     Not available       Not available         Not available  Not available
# 2     Not available       Not available         Not available  Not available
# 3     Not available       Not available         Not available  Not available
# 4     Not available       Not available         Not available  Not available
# ..              ...                 ...                   ...            ...
# 395   Not available       Not available         Not available  Not available
# 396   Not available       Not available         Not available  Not available
# 397   Not available       Not available         Not available  Not available
# 398   Not available       Not available         Not available  Not available
# 399   Not available       Not available         Not available  Not available
#
#      ...  precursor_charge_41  precursor_charge_42  precursor_charge_43  \
# 0    ...                  NaN                  NaN                  NaN
# 1    ...                  NaN                  NaN                  NaN
# 2    ...                  NaN                  NaN                  NaN
# 3    ...                  NaN                  NaN                  NaN
# 4    ...                  NaN                  NaN                  NaN
# ..   ...                  ...                  ...                  ...
# 395  ...                  NaN                  NaN                  NaN
# 396  ...                  NaN                  NaN                  NaN
# 397  ...                  NaN                  NaN                  NaN
# 398  ...                  NaN                  NaN                  NaN
# 399  ...                  NaN                  NaN                  NaN
#
#      precursor_charge_44  precursor_charge_45 precursor_charge_46  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 2                    NaN                  NaN                 NaN
# 3                    NaN                  NaN                 NaN
# 4                    NaN                  NaN                 NaN
# ..                   ...                  ...                 ...
# 395                  NaN                  NaN                 NaN
# 396                  NaN                  NaN                 NaN
# 397                  NaN                  NaN                 NaN
# 398                  NaN                  NaN                 NaN
# 399                  NaN                  NaN                 NaN
#
#      precursor_charge_47  precursor_charge_48  precursor_charge_49  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ..                   ...                  ...                  ...
# 395                  NaN                  NaN                  NaN
# 396                  NaN                  NaN                  NaN
# 397                  NaN                  NaN                  NaN
# 398                  NaN                  NaN                  NaN
# 399                  NaN                  NaN                  NaN
#
#      precursor_charge_50
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 395                  NaN
# 396                  NaN
# 397                  NaN
# 398                  NaN
# 399                  NaN
#
# [400 rows x 64 columns]

# %%
# load metadata and merge with features
metadata = pd.read_csv("../data/metadata/prot_ids_and_pride_meta.csv")
df = metadata.merge(features_df, on="Filename", how="inner")

# load parsed keywords
#keywords_file = "../data/ML_test/keyword_files/keyword_parsing_results.csv"
#keywords_df = pd.read_csv(keywords_file)
#df = keywords_df.merge(df, on="Filename", how="inner")

# preprocessing
label_columns = ["Organism", "Organism part", "Diseases", "Modification", "Instrument","Software",
                 "Experiment Type","Quantification"]
df[label_columns] = df[label_columns].fillna("Not available")
df[label_columns]
# Out:
#                                               Organism  \
# 0                                 Mus musculus (mouse)
# 1    Trypanosoma brucei brucei, Leishmania major st...
# 2                                 Mus musculus (mouse)
# 3                                 Homo sapiens (human)
# 4                                     Escherichia coli
# ..                                                 ...
# 389                               Homo sapiens (human)
# 390                               Homo sapiens (human)
# 391         Homo sapiens (human), Mus musculus (mouse)
# 392                               Homo sapiens (human)
# 393                                     Trichuris suis
#
#                                     Organism part  \
# 0                        Cortex of kidney, Kidney
# 1                                   Not available
# 2                                    Cell culture
# 3           Epithelial cell, Early embryonic cell
# 4                                   Not available
# ..                                            ...
# 389  Substantia nigra, Brain, Dopaminergic neuron
# 390                           Cell culture, Brain
# 391                                 Not available
# 392                                         Brain
# 393                                 Not available
#
#                                             Diseases  \
# 0                               Renal cell carcinoma
# 1                                      Not available
# 2                                      Not available
# 3                                      Not available
# 4                                      Not available
# ..                                               ...
# 389                                    Not available
# 390  Human immunodeficiency virus infectious disease
# 391                                    Not available
# 392                              Alzheimer's disease
# 393                                    Not available
#
#                                           Modification             Instrument  \
# 0    monohydroxylated residue, acetylated residue, ...  Orbitrap Fusion Lumos
# 1                  No PTMs are included in the dataset  Orbitrap Fusion Lumos
# 2                  No PTMs are included in the dataset     LTQ Orbitrap Velos
# 3                              methylthiolated residue             Q Exactive
# 4                  No PTMs are included in the dataset             Q Exactive
# ..                                                 ...                    ...
# 389  monohydroxylated residue, deamidated residue, ...  Orbitrap Fusion Lumos
# 390  monohydroxylated residue, TMT6plex-126 reporte...             Q Exactive
# 391  Gln->pyro-Glu, Carbamyl, TMT6plex, Deamidated,...             Q Exactive
# 392  monohydroxylated residue, phosphorylated resid...     LTQ Orbitrap Velos
# 393                  iodoacetamide derivatized residue             Q Exactive
#
#                                               Software  \
# 0             SEQUEST, Proteome Discoverer, Percolator
# 1                                        Not available
# 2                                               Mascot
# 3                                        Not available
# 4                                        Not available
# ..                                                 ...
# 389                                Andromeda, MaxQuant
# 390                                      Not available
# 391  2.2.0.388 2.2.0.388, Mascot Server 2.4.1, Masc...
# 392                                             Mascot
# 393                                      Not available
#
#                                        Experiment Type  \
# 0                                   Shotgun proteomics
# 1                                   Shotgun proteomics
# 2                                 Gel-based experiment
# 3    Affinity purification coupled with mass spectr...
# 4                                RNA mass spectrometry
# ..                                                 ...
# 389                                 Shotgun proteomics
# 390                                 Shotgun proteomics
# 391                                 Shotgun proteomics
# 392                                 Shotgun proteomics
# 393                               Gel-based experiment
#
#                                         Quantification
# 0                                        precursor ion
# 1                                        Not available
# 2                                        Not available
# 3                                        Not available
# 4                                        Not available
# ..                                                 ...
# 389  MS1 intensity based label-free quantification ...
# 390                                                TMT
# 391                                                TMT
# 392                                  Spectrum counting
# 393                                      Not available
#
# [394 rows x 8 columns]

# %%
### Eucaryote/ Bacteria/ Virus prediction -- Generate labels

domain_mapping = {
    "Homo sapiens (human)": "Eukaryota",
    "Mus musculus (mouse)": "Eukaryota",
    "Arabidopsis thaliana (mouse-ear cress)": "Eukaryota",
    "Escherichia coli": "Bacteria",
    "Rattus norvegicus (rat)": "Eukaryota",
    "Saccharomyces cerevisiae (baker's yeast)": "Eukaryota",
    "Plasmodium berghei anka": "Eukaryota",
    "Bos taurus (bovine)": "Eukaryota",
    "Brassica oleracea var. botrytis (cauliflower)": "Eukaryota",
    "Danio rerio (zebrafish) (brachydanio rerio)": "Eukaryota",
    "Gallus gallus (chicken)": "Eukaryota",
    "Apis mellifera (honeybee)": "Eukaryota",
    "Naja melanoleuca": "Eukaryota",
    "Deinococcus radiodurans r1": "Bacteria",
    "Kalanchoe fedtschenkoi": "Eukaryota",
    "Toxoplasma gondii rh": "Eukaryota",
    "Phaeodactylum tricornutum (strain ccap 1055/1)": "Eukaryota",
    "Mycobacterium avium 104": "Bacteria",
    "Elysia crispata": "Eukaryota",
    "Phormidium sp. oscr": "Bacteria",
    "Norovirus": "Virus",
    "Caenorhabditis elegans": "Eukaryota",
    "Saccostrea glomerata": "Eukaryota",
    "Botryotinia fuckeliana (noble rot fungus) (botrytis cinerea)": "Eukaryota",
    "Candida glabrata (yeast) (torulopsis glabrata)": "Eukaryota",
    "Giardia lamblia atcc 50803": "Eukaryota",
    "Triticum aestivum (wheat)": "Eukaryota",
    "Streptomyces coelicolor": "Bacteria",
    "Coffea canephora": "Eukaryota",
    "Hordeum vulgare (barley)": "Eukaryota",
    "Pisum sativum (garden pea)": "Eukaryota",
    "Brugia malayi": "Eukaryota",
    "Plasmodium vivax": "Eukaryota",
    "Prochlorococcus marinus subsp. pastoris str. ccmp1986": "Bacteria",
    "Cupriavidus necator (strain atcc 17699 / h16 / dsm 428 / stanier 337) (ralstonia eutropha)": "Bacteria",
    "Nicotiana tabacum (common tobacco)": "Eukaryota",
    "Chlamydomonas reinhardtii": "Eukaryota",
    "Sus scrofa domesticus (domestic pig)": "Eukaryota",
    "Pinus pinaster (maritime pine)": "Eukaryota",
    "Emiliania huxleyi": "Eukaryota",
    "Plasmodium berghei": "Eukaryota",
    "[candida] glabrata cbs 138": "Eukaryota",
    "Trichuris suis": "Eukaryota",
    "Methanothrix soehngenii gp6": "Archaea",
    "Clostridium cellulolyticum (strain atcc 35319 / dsm 5812 / jcm 6584 / h10)": "Bacteria",
    "Methanospirillum hungatei jf-1": "Archaea",
    "Desulfovibrio vulgaris str. hildenborough": "Bacteria",
    "Haloferax volcanii (halobacterium volcanii)": "Archaea",
    "Trypanosoma brucei brucei, Leishmania major strain friedlin": "Eukaryota",
    "Toxoplasma gondii": "Eukaryota",
    "Synechococcus sp. (strain wh8102)": "Bacteria",
    "Cryptococcus neoformans var. grubii vni" : "Eukaryota",
    "Rupicapra pyrenaica, Ovis aries musimon, Capra pyrenaica" : "Eukaryota",
    "Streptococcus pyogenes stab901":"Bacteria",
    "Bemisia sp. unknown_th_13_12_s.lycopersicum": "Eukaryota"
}

# Funktion zur Ermittlung der Domain
def get_domain(organism):
    domains = set()
    for key, value in domain_mapping.items():
        if key in organism:
            domains.add(value)
    return ", ".join(domains) if domains else "Unknown"


df["Domain"] = df["Organism"].apply(get_domain)

df[["Organism", "Domain"]].to_csv("../data/metadata/domains.csv")

label_columns = ["Domain","Organism", "Organism part", "Diseases", "Modification", 
                 "Experiment Type", "Instrument", "Quantification", "Software"]

# %% [markdown]
# Get unique count values for label columns to determine baseline (random prediction).

# %%
for col in df[label_columns].columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Domain: 7 unique values
# Organism: 71 unique values
# Organism part: 108 unique values
# Diseases: 56 unique values
# Modification: 88 unique values
# Experiment Type: 27 unique values
# Instrument: 47 unique values
# Quantification: 25 unique values
# Software: 52 unique values

# %% [markdown]
# ### One-Hot-Encoding Organism

# %% [markdown]
# ##### Insert keywords

# %%
# === MODELL SPEICHERN ===
prefix = "org_onehot_400_wkey"
clf_file = f"prometainfer/models/{prefix}_model.pkl"
p_file = f"prometainfer/models/{prefix}_preprocessor.pkl"
enc_file = f"prometainfer/models/{prefix}_label_encoders.pkl"
train_features = f"prometainfer/models/{prefix}_train_features.csv"
keyword_files = "../data/ML_test/keyword_files/keyword_parsing_results.csv"

### add keyword features
keywords_df = pd.read_csv(keyword_files)
organism_df = keywords_df.merge(df, on="Filename", how="inner")

organism_df.to_csv(train_features, index = False)

organism_df = organism_df.drop(columns=["Filename", "PRIDE ID", "Unnamed: 0", "Submission Date",
                     "Publication Date", "Country", "Keywords"] + ['Domain','Organism part',
                                                                   'Diseases','Modification','Experiment Type',
                                                                   'Instrument','Quantification','Software'])

### One-hot encoding
organism_df["Organism"] = organism_df["Organism"].str.split(",")
organism_df = organism_df.explode("Organism")
organism_df = pd.get_dummies(organism_df, columns=["Organism"])
# Aggregate back to original rows (if needed)
#organism_df = organism_df.groupby(organism_df.index).max().reset_index(drop=True)
organism_labels = [col for col in organism_df.columns if col.startswith("Organism")]

print(len(organism_labels))
# Out:
# 86

# %%
# Features & Labels splitten
X = organism_df.drop(columns=organism_labels)
y = organism_df[organism_labels]

# Identify categorical and numeric columns
categorical_cols = X.select_dtypes(include=["object", "category"]).columns
numeric_cols = X.select_dtypes(include=["int64", "float64"]).columns

# Create a ColumnTransformer to preprocess categorical and numeric columns
preprocessor = ColumnTransformer(
    transformers=[
        # Impute NaNs in numeric columns with the mean, then scale
        ("num", Pipeline([
            ("imputer", SimpleImputer(strategy="mean")),  # Impute NaNs with mean
            ("scaler", StandardScaler())  # Scale numeric columns
        ]), numeric_cols),
        
        # Impute NaNs in categorical columns with the most frequent value, then one-hot encode
        ("cat", Pipeline([
            ("imputer", SimpleImputer(strategy="most_frequent")),  # Impute NaNs with mode
            ("onehot", OneHotEncoder(handle_unknown="ignore"))  # One-hot encode categorical columns
        ]), categorical_cols),
    ]
)

# Apply preprocessing to X
X_preprocessed = preprocessor.fit_transform(X)

# === 5. MACHINE LEARNING MODELL TRAINIEREN ===
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=42)

print(X_train.shape)

rf = RandomForestClassifier(n_estimators=100, random_state=42)

rf.fit(X_train, y_train)

# Vorhersagen
y_pred = rf.predict(X_test)

# === 6. PERFORMANCE AUSWERTEN ===
for i, col in enumerate(organism_labels):
    print(f"Classification Report for {col}:")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i], zero_division=0))

# === 7. MODELL SPEICHERN ===
joblib.dump(rf, clf_file)
joblib.dump(preprocessor, p_file)
#joblib.dump(label_encoders, enc_file)
# Out:
# (382, 5645)
# Classification Report for Organism_ Arabidopsis thaliana (mouse-ear cress):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Bacillus cereus:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Bacillus subtilis:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_ Bacillus thuringiensis str. al hakam:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_ Bacteria:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_ Bos taurus (bovine):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Capra pyrenaica:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Cercopithecus aethiops (green monkey) (grivet):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Chlamydomonas reinhardtii:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Chlorocebus sabaeus:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Clostridium cellulolyticum (strain atcc 35319 / dsm 5812 / jcm 6584 / h10):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Cyanidioschyzon merolae:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Desulfovibrio vulgaris str. hildenborough:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Entamoeba histolytica hm-1:imss-a:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        96
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.99        96
#    macro avg       0.50      0.49      0.50        96
# weighted avg       1.00      0.99      0.99        96
#
# Classification Report for Organism_ Escherichia coli:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_ Escherichia phage t4:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_ Homo sapiens (human):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Japanese encephalitis virus:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        96
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.99        96
#    macro avg       0.50      0.49      0.50        96
# weighted avg       1.00      0.99      0.99        96
#
# Classification Report for Organism_ Leishmania major strain friedlin:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Methanospirillum hungatei jf-1:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Mus musculus (mouse):
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.98        96
#    macro avg       0.49      0.49      0.49        96
# weighted avg       0.98      0.98      0.98        96
#
# Classification Report for Organism_ Nicotiana benthamiana:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Ovis aries musimon:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Pan troglodytes (chimpanzee):
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_ Pisum sativum (garden pea):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Porphyrobacter sp. wlsh-3:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Pseudomonas putida kt2440:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        96
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.99        96
#    macro avg       0.50      0.49      0.50        96
# weighted avg       1.00      0.99      0.99        96
#
# Classification Report for Organism_ Rattus norvegicus (rat):
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_ Saccharomyces cerevisiae (baker's yeast):
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        96
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.99        96
#    macro avg       0.50      0.49      0.50        96
# weighted avg       1.00      0.99      0.99        96
#
# Classification Report for Organism_ Salmonella enterica subsp. enterica serovar typhimurium str. atcc 14028:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_ Sus scrofa domesticus (domestic pig):
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        96
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.99        96
#    macro avg       0.50      0.49      0.50        96
# weighted avg       1.00      0.99      0.99        96
#
# Classification Report for Organism_Apis mellifera (honeybee):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Arabidopsis thaliana (mouse-ear cress):
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        91
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.95        96
#    macro avg       0.47      0.50      0.49        96
# weighted avg       0.90      0.95      0.92        96
#
# Classification Report for Organism_Bacillus thuringiensis:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Bemisia sp. unknown_th_13_12_s.lycopersicum:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Bos taurus (bovine):
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Botryotinia fuckeliana (noble rot fungus) (botrytis cinerea):
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Brassica oleracea var. botrytis (cauliflower):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Brugia malayi:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Caenorhabditis elegans:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Candida glabrata (yeast) (torulopsis glabrata):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Chlamydomonas reinhardtii:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Coffea canephora:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Cryptococcus neoformans var. grubii vni:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Cupriavidus necator (strain atcc 17699 / h16 / dsm 428 / stanier 337) (ralstonia eutropha):
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Danio rerio (zebrafish) (brachydanio rerio):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Deinococcus radiodurans r1:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Elysia crispata:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Emiliania huxleyi:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Escherichia coli:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        92
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.97        96
#    macro avg       0.98      0.62      0.69        96
# weighted avg       0.97      0.97      0.96        96
#
# Classification Report for Organism_Gallus gallus (chicken):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Giardia lamblia atcc 50803:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Haloferax volcanii (halobacterium volcanii):
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Homo sapiens (human):
#               precision    recall  f1-score   support
#
#            0       0.71      0.92      0.80        50
#            1       0.87      0.59      0.70        46
#
#     accuracy                           0.76        96
#    macro avg       0.79      0.75      0.75        96
# weighted avg       0.79      0.76      0.75        96
#
# Classification Report for Organism_Hordeum vulgare (barley):
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        96
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.99        96
#    macro avg       0.50      0.49      0.50        96
# weighted avg       1.00      0.99      0.99        96
#
# Classification Report for Organism_Kalanchoe fedtschenkoi:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Methanothrix soehngenii gp6:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Mus musculus (mouse):
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        89
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.93        96
#    macro avg       0.46      0.50      0.48        96
# weighted avg       0.86      0.93      0.89        96
#
# Classification Report for Organism_Mycobacterium avium 104:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Naja melanoleuca:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Nicotiana tabacum (common tobacco):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Norovirus:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Phaeodactylum tricornutum (strain ccap 1055/1):
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Phormidium sp. oscr:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Pinus pinaster (maritime pine):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Pisum sativum (garden pea):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Plasmodium berghei:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Plasmodium berghei anka:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Plasmodium vivax:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Prochlorococcus marinus subsp. pastoris str. ccmp1986:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Rattus norvegicus (rat):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        95
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Rupicapra pyrenaica:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Saccharomyces cerevisiae (baker's yeast):
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        92
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.96        96
#    macro avg       0.48      0.50      0.49        96
# weighted avg       0.92      0.96      0.94        96
#
# Classification Report for Organism_Saccostrea glomerata:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Salmonella enterica:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Sediment metagenome:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Streptococcus pyogenes stab901:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Streptomyces coelicolor:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Sus scrofa domesticus (domestic pig):
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Synechococcus sp. (strain wh8102):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Toxoplasma gondii:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Toxoplasma gondii rh:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
#
# Classification Report for Organism_Trichuris suis:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_Triticum aestivum (wheat):
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        94
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.98        96
#    macro avg       0.49      0.50      0.49        96
# weighted avg       0.96      0.98      0.97        96
#
# Classification Report for Organism_Trypanosoma brucei brucei:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        96
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96
#
# Classification Report for Organism_[candida] glabrata cbs 138:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        95
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        96
#    macro avg       0.49      0.50      0.50        96
# weighted avg       0.98      0.99      0.98        96
# ['prometainfer/models/org_onehot_400_wkey_preprocessor.pkl']

# %%
numeric_feature_names = numeric_cols.tolist()
onehot_encoder = preprocessor.named_transformers_['cat'].named_steps['onehot']

try:
    categorical_feature_names = onehot_encoder.get_feature_names_out(categorical_cols)
except AttributeError:
    categorical_feature_names = []
    for i, col in enumerate(categorical_cols):
        categories = onehot_encoder.categories_[i]
        categorical_feature_names.extend([f"{col}_{cat}" for cat in categories])

all_feature_names = numeric_feature_names + categorical_feature_names
print(len(all_feature_names),"Finale Feature-Namen:", all_feature_names)
# Out:
# 5645 Finale Feature-Namen: ['iTRAQ', 'SILAC', 'SWATH', 'phospho', 'acetyl', 'methyl', 'glygly', 'oxidation', 'carbamidomethyl', '+15.99', '+79.97', '+42.01', '+14.02', '+114.04', '+57.02', 'human', 'mouse', 'rat', 'yeast', 'bacteria', 'virus', 'fly', 'liver', 'kidney', 'brain', 'heart', 'lung', 'plasma', 'serum', 'cancer', 'RAT_counthits', 'RAT_avgevalhits', 'HUMAN_counthits', 'HUMAN_avgevalhits', 'CANLF_counthits', 'CANLF_avgevalhits', 'MOUSE_counthits', 'MOUSE_avgevalhits', 'CHICK_counthits', 'CHICK_avgevalhits', 'HORSE_counthits', 'HORSE_avgevalhits', 'BOVIN_counthits', 'BOVIN_avgevalhits', 'RABIT_counthits', 'RABIT_avgevalhits', 'PANTR_counthits', 'PANTR_avgevalhits', 'DESRO_counthits', 'DESRO_avgevalhits', 'FELCA_counthits', 'FELCA_avgevalhits', 'PONAB_counthits', 'PONAB_avgevalhits', 'MACMU_counthits', 'MACMU_avgevalhits', 'MACFA_counthits', 'MACFA_avgevalhits', 'XENLA_counthits', 'XENLA_avgevalhits', 'PIG_counthits', 'PIG_avgevalhits', 'MACNE_counthits', 'MACNE_avgevalhits', 'COTJA_counthits', 'COTJA_avgevalhits', 'GORGO_counthits', 'GORGO_avgevalhits', 'PAPHA_counthits', 'PAPHA_avgevalhits', 'AOTNA_counthits', 'AOTNA_avgevalhits', 'PANPA_counthits', 'PANPA_avgevalhits', 'SHEEP_counthits', 'SHEEP_avgevalhits', 'SPAJD_counthits', 'SPAJD_avgevalhits', 'MESAU_counthits', 'MESAU_avgevalhits', 'AQUCT_counthits', 'AQUCT_avgevalhits', 'ANAPL_counthits', 'ANAPL_avgevalhits', 'STAAM_counthits', 'STAAM_avgevalhits', 'STAAW_counthits', 'STAAW_avgevalhits', 'STAAC_counthits', 'STAAC_avgevalhits', 'STAAS_counthits', 'STAAS_avgevalhits', 'STAAR_counthits', 'STAAR_avgevalhits', 'STAAU_counthits', 'STAAU_avgevalhits', 'STAA8_counthits', 'STAA8_avgevalhits', 'STAAN_counthits', 'STAAN_avgevalhits', 'BACSU_counthits', 'BACSU_avgevalhits', 'POLSJ_counthits', 'POLSJ_avgevalhits', 'ACIAN_counthits', 'ACIAN_avgevalhits', 'SALTI_counthits', 'SALTI_avgevalhits', 'ECOLX_counthits', 'ECOLX_avgevalhits', 'KLESP_counthits', 'KLESP_avgevalhits', 'ACIBA_counthits', 'ACIBA_avgevalhits', 'SQUAC_counthits', 'SQUAC_avgevalhits', 'HALH5_counthits', 'HALH5_avgevalhits', 'STAES_counthits', 'STAES_avgevalhits', 'STAEQ_counthits', 'STAEQ_avgevalhits', 'STAAE_counthits', 'STAAE_avgevalhits', 'PNECA_counthits', 'PNECA_avgevalhits', 'HELTB_counthits', 'HELTB_avgevalhits', 'MESFR_counthits', 'MESFR_avgevalhits', 'ABSGL_counthits', 'ABSGL_avgevalhits', 'ARTSX_counthits', 'ARTSX_avgevalhits', 'ONCVO_counthits', 'ONCVO_avgevalhits', 'LUMTE_counthits', 'LUMTE_avgevalhits', 'BACDO_counthits', 'BACDO_avgevalhits', 'HALRO_counthits', 'HALRO_avgevalhits', 'BOMMO_counthits', 'BOMMO_avgevalhits', 'AEDAE_counthits', 'AEDAE_avgevalhits', 'DICDI_counthits', 'DICDI_avgevalhits', 'CAEEL_counthits', 'CAEEL_avgevalhits', 'DROME_counthits', 'DROME_avgevalhits', 'ACACA_counthits', 'ACACA_avgevalhits', 'DIBDE_counthits', 'DIBDE_avgevalhits', 'ECHGR_counthits', 'ECHGR_avgevalhits', 'PODCA_counthits', 'PODCA_avgevalhits', 'HELER_counthits', 'HELER_avgevalhits', 'PSEAB_counthits', 'PSEAB_avgevalhits', 'PSEAE_counthits', 'PSEAE_avgevalhits', 'BARQU_counthits', 'BARQU_avgevalhits', 'BARHE_counthits', 'BARHE_avgevalhits', 'CALJA_counthits', 'CALJA_avgevalhits', 'STAHJ_counthits', 'STAHJ_avgevalhits', 'STAWA_counthits', 'STAWA_avgevalhits', 'STACT_counthits', 'STACT_avgevalhits', 'COLLI_counthits', 'COLLI_avgevalhits', 'CRIGR_counthits', 'CRIGR_avgevalhits', 'SPECI_counthits', 'SPECI_avgevalhits', 'GLOMM_counthits', 'GLOMM_avgevalhits', 'MELGA_counthits', 'MELGA_avgevalhits', 'PELSI_counthits', 'PELSI_avgevalhits', 'MUSPF_counthits', 'MUSPF_avgevalhits', 'GLORO_counthits', 'GLORO_avgevalhits', 'BACC3_counthits', 'BACC3_avgevalhits', 'BACC0_counthits', 'BACC0_avgevalhits', 'EXISA_counthits', 'EXISA_avgevalhits', 'LACGA_counthits', 'LACGA_avgevalhits', 'BACC2_counthits', 'BACC2_avgevalhits', 'BACAH_counthits', 'BACAH_avgevalhits', 'BACCQ_counthits', 'BACCQ_avgevalhits', 'LACJO_counthits', 'LACJO_avgevalhits', 'BACC1_counthits', 'BACC1_avgevalhits', 'BACCZ_counthits', 'BACCZ_avgevalhits', 'BA ...

# %%
# Vorhersagen zurück in DataFrame umwandeln
y_pred_df = pd.DataFrame(y_pred, columns=organism_labels, index=y_test.index)

# Echte Labels auch als DataFrame
y_test_df = pd.DataFrame(y_test, columns=organism_labels, index=y_test.index)

def one_hot_to_labels(df, labels):
    return df.apply(lambda row: ", ".join([labels[i] for i in range(len(row)) if row[i] == 1]), axis=1)

# Erstelle eine Spalte mit den vorhergesagten Organismen
y_pred_labels = one_hot_to_labels(y_pred_df, organism_labels)

# Erstelle eine Spalte mit den tatsächlichen Organismen
y_test_labels = one_hot_to_labels(y_test_df, organism_labels)

# Berechnung der Accuracy (Anteil korrekt vorhergesagter vollständiger Organismus-Sets)
overall_accuracy = (y_pred_labels == y_test_labels).mean()

print(f"Overall Accuracy: {overall_accuracy:.4f}")
# Out:
# Overall Accuracy: 0.3021

# %%
mask = [pred is not None and pred != "" for pred in y_pred_labels]

# Alternativ, wenn es numpy Arrays sind:
# mask = ~np.array([pred is None or pred == "" for pred in y_pred_labels])

# Nur gültige Einträge auswählen
valid_y_pred = np.array(y_pred_labels)[mask]
valid_y_test = np.array(y_test_labels)[mask]

# Accuracy berechnen
overall_accuracy = (valid_y_pred == valid_y_test).mean()
print(overall_accuracy)
print(sum(mask), len(mask))
# Out:
# 0.725
# 40 96

# %%
((96-40) * 0.4 + 40 * 0.725)/96
# Out:
# 0.5354166666666668

# %% [markdown]
# ### One-Hot-Encoding for Instrument

# %%
# === save model ===
prefix = "ins_onehot_400_wkey"
#clf_file = f"prometainfer/models/{prefix}_model.pkl"
#p_file = f"prometainfer/models/{prefix}_preprocessor.pkl"
#enc_file = f"prometainfer/models/{prefix}_label_encoders.pkl"
train_features = f"prometainfer/models/{prefix}_train_features.csv"
#keyword_files = "../data/ML_test/keyword_files/keyword_parsing_results.csv"

clf_file = 'prometainfer/models/ins_onehot_400_wkey_model.pkl'
p_file = 'prometainfer/models/ins_onehot_400_wkey_preprocessor.pkl'
### add keyword features
keywords_df = pd.read_csv(keyword_files)

instrument_df = keywords_df.merge(df, on="Filename", how="inner")

instrument_df.to_csv(train_features, index = False)

instrument_df = instrument_df.drop(columns=["Filename", "PRIDE ID", "Unnamed: 0", "Submission Date",
                     "Publication Date", "Country", "Keywords"] + ['Domain','Organism','Organism part',
                                                                   'Diseases','Modification','Experiment Type',
                                                                   'Quantification','Software'])

### One-hot encoding
instrument_df["Instrument"] = instrument_df["Instrument"].str.split(",")
instrument_df = instrument_df.explode("Instrument")
instrument_df = pd.get_dummies(instrument_df, columns=["Instrument"])
# Aggregate back to original rows (if needed)
#organism_df = organism_df.groupby(organism_df.index).max().reset_index(drop=True)
instrument_labels = [col for col in instrument_df.columns if col.startswith("Instrument")]

print(len(instrument_labels))
# split features and labels
X = instrument_df.drop(columns=instrument_labels)
y = instrument_df[instrument_labels]

# Identify categorical and numeric columns
categorical_cols = X.select_dtypes(include=["object", "category"]).columns
numeric_cols = X.select_dtypes(include=["int64", "float64"]).columns

# Create a ColumnTransformer to preprocess categorical and numeric columns
preprocessor = ColumnTransformer(
    transformers=[
        # Impute NaNs in numeric columns with the mean, then scale
        ("num", Pipeline([
            ("imputer", SimpleImputer(strategy="mean")),  # Impute NaNs with mean
            ("scaler", StandardScaler())  # Scale numeric columns
        ]), numeric_cols),
        
        # Impute NaNs in categorical columns with the most frequent value, then one-hot encode
        ("cat", Pipeline([
            ("imputer", SimpleImputer(strategy="most_frequent")),  # Impute NaNs with mode
            ("onehot", OneHotEncoder(handle_unknown="ignore"))  # One-hot encode categorical columns
        ]), categorical_cols),
    ]
)

# Apply preprocessing to X
X_preprocessed = preprocessor.fit_transform(X)

# === train ML Model ===
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=42)

print(X_train.shape)

rf = RandomForestClassifier(n_estimators=100, random_state=42)

rf.fit(X_train, y_train)

# predict
y_pred = rf.predict(X_test)

# === evaluate performance===
for i, col in enumerate(instrument_labels):
    print(f"Classification Report for {col}:")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i], zero_division=0))

# ===save model ===
joblib.dump(rf, clf_file)
joblib.dump(preprocessor, p_file)
#joblib.dump(label_encoders, enc_file)


y_pred_df = pd.DataFrame(y_pred, columns=instrument_labels, index=y_test.index)


y_test_df = pd.DataFrame(y_test, columns=instrument_labels, index=y_test.index)

def one_hot_to_labels(df, labels):
    return df.apply(lambda row: ", ".join([labels[i] for i in range(len(row)) if row[i] == 1]), axis=1)


y_pred_labels = one_hot_to_labels(y_pred_df, instrument_labels)


y_test_labels = one_hot_to_labels(y_test_df, instrument_labels)

# calculate accuracy over all org labels
overall_accuracy = (y_pred_labels == y_test_labels).mean()

print(f"Overall Accuracy: {overall_accuracy:.4f}")

mask = [pred is not None and pred != "" for pred in y_pred_labels]


# only select non-empty values
valid_y_pred = np.array(y_pred_labels)[mask]
valid_y_test = np.array(y_test_labels)[mask]

# Accuracy
overall_accuracy = (valid_y_pred == valid_y_test).mean()
print(overall_accuracy)
print(sum(mask), len(mask))
# Out:
# 46
# (339, 5645)
# Classification Report for Instrument_ 6330 Ion Trap LC/MS:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        85
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.98        85
#    macro avg       0.50      0.49      0.49        85
# weighted avg       1.00      0.98      0.99        85
#
# Classification Report for Instrument_ LTQ:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_ LTQ Orbitrap:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98        81
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.95        85
#    macro avg       0.48      0.50      0.49        85
# weighted avg       0.91      0.95      0.93        85
#
# Classification Report for Instrument_ LTQ Orbitrap Elite:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_ Orbitrap Exploris 480:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_ Orbitrap Fusion:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        84
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        85
#    macro avg       0.49      0.50      0.50        85
# weighted avg       0.98      0.99      0.98        85
#
# Classification Report for Instrument_ Q Exactive:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98        84
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.96        85
#    macro avg       0.49      0.49      0.49        85
# weighted avg       0.98      0.96      0.97        85
#
# Classification Report for Instrument_ Q Exactive HF:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        85
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.99        85
#    macro avg       0.50      0.49      0.50        85
# weighted avg       1.00      0.99      0.99        85
#
# Classification Report for Instrument_ TripleTOF 5600:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_ solariX:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_4800 Plus MALDI TOF/TOF:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_4800 Proteomics Analyzer:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        84
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_6220 Time-of-Flight LC/MS:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_6490 Triple Quadrupole LC/MS:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        84
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        85
#    macro avg       0.49      0.50      0.50        85
# weighted avg       0.98      0.99      0.98        85
#
# Classification Report for Instrument_6510 Quadrupole Time-of-Flight LC/MS:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        83
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.98        85
#    macro avg       0.49      0.50      0.49        85
# weighted avg       0.95      0.98      0.96        85
#
# Classification Report for Instrument_6540 Q-TOF LC/MS:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_6550 iFunnel Q-TOF LC/MS:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        84
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        85
#    macro avg       0.49      0.50      0.50        85
# weighted avg       0.98      0.99      0.98        85
#
# Classification Report for Instrument_Bruker Daltonics amaZon series:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        85
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.98        85
#    macro avg       0.50      0.49      0.49        85
# weighted avg       1.00      0.98      0.99        85
#
# Classification Report for Instrument_LTQ:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_LTQ Orbitrap:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98        83
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.96        85
#    macro avg       0.49      0.49      0.49        85
# weighted avg       0.95      0.96      0.96        85
#
# Classification Report for Instrument_LTQ Orbitrap Elite:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        84
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        85
#    macro avg       0.49      0.50      0.50        85
# weighted avg       0.98      0.99      0.98        85
#
# Classification Report for Instrument_LTQ Orbitrap Velos:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        80
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.94        85
#    macro avg       0.47      0.50      0.48        85
# weighted avg       0.89      0.94      0.91        85
#
# Classification Report for Instrument_LTQ Orbitrap XL:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        84
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        85
#    macro avg       0.49      0.50      0.50        85
# weighted avg       0.98      0.99      0.98        85
#
# Classification Report for Instrument_LTQ Velos:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_Orbitrap Astral:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_Orbitrap Eclipse:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        82
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.96        85
#    macro avg       0.48      0.50      0.49        85
# weighted avg       0.93      0.96      0.95        85
#
# Classification Report for Instrument_Orbitrap Exploris 240:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        84
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        85
#    macro avg       0.49      0.50      0.50        85
# weighted avg       0.98      0.99      0.98        85
#
# Classification Report for Instrument_Orbitrap Exploris 480:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        83
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.98        85
#    macro avg       0.49      0.50      0.49        85
# weighted avg       0.95      0.98      0.96        85
#
# Classification Report for Instrument_Orbitrap Fusion:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        72
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.85        85
#    macro avg       0.42      0.50      0.46        85
# weighted avg       0.72      0.85      0.78        85
#
# Classification Report for Instrument_Orbitrap Fusion ETD:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        84
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        85
#    macro avg       0.49      0.50      0.50        85
# weighted avg       0.98      0.99      0.98        85
#
# Classification Report for Instrument_Orbitrap Fusion Lumos:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94        73
#            1       0.75      0.25      0.38        12
#
#     accuracy                           0.88        85
#    macro avg       0.82      0.62      0.66        85
# weighted avg       0.87      0.88      0.86        85
#
# Classification Report for Instrument_Progenesis LC-MS:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_Q Exactive:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.90        62
#            1       0.85      0.48      0.61        23
#
#     accuracy                           0.84        85
#    macro avg       0.84      0.72      0.75        85
# weighted avg       0.84      0.84      0.82        85
#
# Classification Report for Instrument_Q Exactive HF:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        79
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.93        85
#    macro avg       0.46      0.50      0.48        85
# weighted avg       0.86      0.93      0.90        85
#
# Classification Report for Instrument_Q Exactive Plus:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        84
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        85
#    macro avg       0.49      0.50      0.50        85
# weighted avg       0.98      0.99      0.98        85
#
# Classification Report for Instrument_Q-Tof Ultima:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        84
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        85
#    macro avg       0.49      0.50      0.50        85
# weighted avg       0.98      0.99      0.98        85
#
# Classification Report for Instrument_QSTAR:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_Synapt G2 HDMS:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_Synapt MS:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        84
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.98        85
#    macro avg       0.49      0.49      0.49        85
# weighted avg       0.98      0.98      0.98        85
#
# Classification Report for Instrument_Thermo Fisher Scientific instrument model:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_TripleTOF 5600:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_X500R QTOF:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_impact HD:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_maXis:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        84
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        85
#    macro avg       0.49      0.50      0.50        85
# weighted avg       0.98      0.99      0.98        85
#
# Classification Report for Instrument_timsTOF Pro:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Classification Report for Instrument_timsTOF Pro 2:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85
#
# Overall Accuracy: 0.1765
# 0.5555555555555556
# 27 85

# %%
((85-27)*0.39 + 27* 0.555555)/ 85
# Out:
# 0.4425880588235294

# %% [markdown]
# ### Same for One-Hot-Encoding for Modification

# %%
clf_file = 'prometainfer/models/mod_onehot_400_wkey_model.pkl'
p_file = 'prometainfer/models/mod_onehot_400_wkey_preprocessor.pkl'

### add keyword features
keywords_df = pd.read_csv(keyword_files)
mod_df = keywords_df.merge(df, on="Filename", how="inner")

#mod_df.to_csv(train_features, index = False)

mod_df = mod_df.drop(columns=["Filename", "PRIDE ID", "Unnamed: 0", "Submission Date",
                     "Publication Date", "Country", "Keywords"] + ['Domain','Organism','Organism part',
                                                                   'Diseases','Instrument','Experiment Type',
                                                                   'Quantification','Software'])

### One-hot encoding
mod_df["Modification"] = mod_df["Modification"].str.split(",")
mod_df = mod_df.explode("Modification")
mod_df = pd.get_dummies(mod_df, columns=["Modification"])

# Aggregate back to original rows (if needed)
mod_labels = [col for col in mod_df.columns if col.startswith("Modification")]

print(len(mod_labels))

X = mod_df.drop(columns=mod_labels)
y = mod_df[mod_labels]

# Identify categorical and numeric columns
categorical_cols = X.select_dtypes(include=["object", "category"]).columns
numeric_cols = X.select_dtypes(include=["int64", "float64"]).columns

# Create a ColumnTransformer to preprocess categorical and numeric columns
preprocessor = ColumnTransformer(
    transformers=[
        ("num", Pipeline([
            ("imputer", SimpleImputer(strategy="mean")),
            ("scaler", StandardScaler())
        ]), numeric_cols),
        
        ("cat", Pipeline([
            ("imputer", SimpleImputer(strategy="most_frequent")),
            ("onehot", OneHotEncoder(handle_unknown="ignore"))
        ]), categorical_cols),
    ]
)

# Apply preprocessing to X
X_preprocessed = preprocessor.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=42)

print(X_train.shape)

rf = RandomForestClassifier(n_estimators=100, random_state=42)

rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

for i, col in enumerate(mod_labels):
    print(f"Classification Report for {col}:")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i], zero_division=0))

joblib.dump(rf, clf_file)
joblib.dump(preprocessor, p_file)

y_pred_df = pd.DataFrame(y_pred, columns=mod_labels, index=y_test.index)

y_test_df = pd.DataFrame(y_test, columns=mod_labels, index=y_test.index)

def one_hot_to_labels(df, labels):
    return df.apply(lambda row: ", ".join([labels[i] for i in range(len(row)) if row[i] == 1]), axis=1)

y_pred_labels = one_hot_to_labels(y_pred_df, mod_labels)

y_test_labels = one_hot_to_labels(y_test_df, mod_labels)

overall_accuracy = (y_pred_labels == y_test_labels).mean()
print(f"Overall Accuracy: {overall_accuracy:.4f}")

mask = [pred is not None and pred != "" for pred in y_pred_labels]

valid_y_pred = np.array(y_pred_labels)[mask]
valid_y_test = np.array(y_test_labels)[mask]

overall_accuracy = (valid_y_pred == valid_y_test).mean()
print(overall_accuracy)
print(sum(mask), len(mask))
# Out:
# 83
# (723, 5645)
# Classification Report for Modification_ (R)-5-oxo-1:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ 6x(13)C:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ 6x(13)C labeled residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ Acetyl:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       175
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.97       181
#    macro avg       0.48      0.50      0.49       181
# weighted avg       0.93      0.97      0.95       181
#
# Classification Report for Modification_ Acetyl:2H(3):
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_ Biotin:Sigma-B1267:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ Carbamidomethyl:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       168
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.93       181
#    macro avg       0.46      0.50      0.48       181
# weighted avg       0.86      0.93      0.89       181
#
# Classification Report for Modification_ Carbamyl:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ Deamidated:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       179
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       181
#    macro avg       0.49      0.50      0.50       181
# weighted avg       0.98      0.99      0.98       181
#
# Classification Report for Modification_ Glu->pyro-Glu:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_ GlyGly:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ L-methionine sulfoxide:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_ Met-loss:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ Methyl:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ N-acetyl-L-methionine:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_ N-acetylaminohexosylated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ N6-[3-(carboxamidomethylthio)propanoyl]lysine:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ O-(N-acetylamino)galactosyl-L-threonine:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ Oxidation:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       171
#            1       0.00      0.00      0.00        10
#
#     accuracy                           0.94       181
#    macro avg       0.47      0.50      0.48       181
# weighted avg       0.89      0.94      0.92       181
#
# Classification Report for Modification_ Phospho:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       179
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       181
#    macro avg       0.49      0.50      0.50       181
# weighted avg       0.98      0.99      0.98       181
#
# Classification Report for Modification_ Propionamide:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ Pyro-carbamidomethyl:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ S-carboxamidoethyl-L-cysteine:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       179
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.98       181
#    macro avg       0.49      0.50      0.50       181
# weighted avg       0.98      0.98      0.98       181
#
# Classification Report for Modification_ S-carboxamidomethyl-L-cysteine:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       181
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.49      0.50       181
# weighted avg       1.00      0.99      0.99       181
#
# Classification Report for Modification_ TMT6plex:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       179
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       181
#    macro avg       0.49      0.50      0.50       181
# weighted avg       0.98      0.99      0.98       181
#
# Classification Report for Modification_ TMT6plex-126 reporter+balance reagent acylated residue:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       179
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       181
#    macro avg       0.49      0.50      0.50       181
# weighted avg       0.98      0.99      0.98       181
#
# Classification Report for Modification_ acetylated residue:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       170
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.92       181
#    macro avg       0.47      0.49      0.48       181
# weighted avg       0.88      0.92      0.90       181
#
# Classification Report for Modification_ alpha-amino acetylated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ alpha-amino monomethylated residue:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_ alpha-amino trimethylated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ amidated residue:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_ carbamoylated residue:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       178
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.98       181
#    macro avg       0.49      0.50      0.49       181
# weighted avg       0.97      0.98      0.97       181
#
# Classification Report for Modification_ complex glycosylation:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_ deamidated residue:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       175
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.96       181
#    macro avg       0.48      0.49      0.49       181
# weighted avg       0.93      0.96      0.95       181
#
# Classification Report for Modification_ deoxyhexosylated residue:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_ iTRAQ4plex-116 reporter+balance reagent acylated residue:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_ iTRAQ8plex-116 reporter+balance reagent acylated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ iodoacetamide derivatized residue:
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       155
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.73       181
#    macro avg       0.42      0.43      0.42       181
# weighted avg       0.72      0.73      0.73       181
#
# Classification Report for Modification_ iodoacetic acid derivatized residue:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_ methylthiolated residue:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       179
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       181
#    macro avg       0.49      0.50      0.50       181
# weighted avg       0.98      0.99      0.98       181
#
# Classification Report for Modification_ mono N-acetylated residue:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_ monohydroxylated residue:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_ monomethylated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ myristoylated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ oxygenated residue:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_ palmitoylated residue:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_ phosphorylated residue:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       175
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.97       181
#    macro avg       0.48      0.50      0.49       181
# weighted avg       0.93      0.97      0.95       181
#
# Classification Report for Modification_ sulfated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_ ubiquitinylated lysine:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_4-tetrahydrothiazine-3-carboxylic acid:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_6x(13)C:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_6x(13)C labeled residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_Carbamidomethyl:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_Deamidated:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_Dioxidation:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_Gln->pyro-Glu:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_L-methionine sulfoxide:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_MappingA:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_Met-loss+Acetyl:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_N-acetylhexosaminylated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       181
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       1.00      0.99      1.00       181
#
# Classification Report for Modification_No PTMs are included in the dataset:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       167
#            1       1.00      0.21      0.35        14
#
#     accuracy                           0.94       181
#    macro avg       0.97      0.61      0.66       181
# weighted avg       0.94      0.94      0.92       181
#
# Classification Report for Modification_Not available:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_O-(N-acetylamino)galactosyl-L-serine:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_O-(phospho-5'-adenosine)-L-threonine:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_Oxidation:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_Phospho:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_TMT2plex:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_TMT6plex:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_TMT6plex-126 reporter+balance reagent acylated residue:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_acetylated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       181
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       1.00      0.99      1.00       181
#
# Classification Report for Modification_alpha-amino dimethylated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_carboxylated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_deamidated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       181
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       1.00      0.99      1.00       181
#
# Classification Report for Modification_deoxyhexosylated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_iTRAQ8plex-116 reporter+balance reagent acylated residue:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       180
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       181
#    macro avg       0.50      0.50      0.50       181
# weighted avg       0.99      0.99      0.99       181
#
# Classification Report for Modification_iodoacetamide derivatized residue:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96       168
#            1       0.50      0.08      0.13        13
#
#     accuracy                           0.93       181
#    macro avg       0.72      0.54      0.55       181
# weighted avg       0.90      0.93      0.90       181
#
# Classification Report for Modification_iodoacetic acid derivatized residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_methylated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_methylthiolated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_monohydroxylated residue:
#               precision    recall  f1-score   support
#
#            0       0.79      0.91      0.84       145
#            1       0.00      0.00      0.00        36
#
#     accuracy                           0.73       181
#    macro avg       0.39      0.46      0.42       181
# weighted avg       0.63      0.73      0.68       181
#
# Classification Report for Modification_monomethylated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_palmitoylated residue:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Classification Report for Modification_phosphorylated residue:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       178
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.97       181
#    macro avg       0.49      0.49      0.49       181
# weighted avg       0.97      0.97      0.97       181
#
# Overall Accuracy: 0.0221
# 0.07017543859649122
# 57 181

# %% [markdown]
# ### One-Hot-Encoding for Experiment Type

# %%
prefix = "exp_onehot_400_wkey"
#clf_file = f"prometainfer/models/{prefix}_model.pkl"
#p_file = f"prometainfer/models/{prefix}_preprocessor.pkl"
#enc_file = f"prometainfer/models/{prefix}_label_encoders.pkl"
train_features = f"prometainfer/models/{prefix}_train_features.csv"
#keyword_files = "../data/ML_test/keyword_files/keyword_parsing_results.csv"


clf_file = 'prometainfer/models/exp_onehot_400_wkey_model.pkl'
p_file = 'prometainfer/models/exp_onehot_400_wkey_preprocessor.pkl'

### add keyword features
keywords_df = pd.read_csv(keyword_files)
exp_df = keywords_df.merge(df, on="Filename", how="inner")

exp_df.to_csv(train_features, index = False)

exp_df = exp_df.drop(columns=["Filename", "PRIDE ID", "Unnamed: 0", "Submission Date",
                     "Publication Date", "Country", "Keywords"] + ['Domain','Organism','Organism part',
                                                                   'Diseases','Instrument','Modification',
                                                                   'Quantification','Software'])

### One-hot encoding
exp_df["Experiment Type"] = exp_df["Experiment Type"].str.split(",")
exp_df = exp_df.explode("Experiment Type")
exp_df = pd.get_dummies(exp_df, columns=["Experiment Type"])

# Aggregate back to original rows (if needed)
exp_labels = [col for col in exp_df.columns if col.startswith("Experiment Type")]

print(len(exp_labels))

# Features & Labels splitten
X = exp_df.drop(columns=exp_labels)
y = exp_df[exp_labels]


# Identify categorical and numeric columns
categorical_cols = X.select_dtypes(include=["object", "category"]).columns
numeric_cols = X.select_dtypes(include=["int64", "float64"]).columns

# Create a ColumnTransformer to preprocess categorical and numeric columns
preprocessor = ColumnTransformer(
    transformers=[
        ("num", Pipeline([
            ("imputer", SimpleImputer(strategy="mean")),
            ("scaler", StandardScaler())
        ]), numeric_cols),
        
        ("cat", Pipeline([
            ("imputer", SimpleImputer(strategy="most_frequent")),
            ("onehot", OneHotEncoder(handle_unknown="ignore"))
        ]), categorical_cols),
    ]
)

# Apply preprocessing to X
X_preprocessed = preprocessor.fit_transform(X)

# === 5. MACHINE LEARNING MODELL TRAINIEREN ===
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=42)

print(X_train.shape)

rf = RandomForestClassifier(n_estimators=100, random_state=42)

rf.fit(X_train, y_train)

# Vorhersagen
y_pred = rf.predict(X_test)

# === 6. PERFORMANCE AUSWERTEN ===
for i, col in enumerate(exp_labels):
    print(f"Classification Report for {col}:")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i], zero_division=0))

# === 7. MODELL SPEICHERN ===
joblib.dump(rf, clf_file)
joblib.dump(preprocessor, p_file)

# Vorhersagen zurück in DataFrame umwandeln
y_pred_df = pd.DataFrame(y_pred, columns=exp_labels, index=y_test.index)

y_test_df = pd.DataFrame(y_test, columns=exp_labels, index=y_test.index)

def one_hot_to_labels(df, labels):
    return df.apply(lambda row: ", ".join([labels[i] for i in range(len(row)) if row[i] == 1]), axis=1)

# Erstelle eine Spalte mit den vorhergesagten Experimentstypen
y_pred_labels = one_hot_to_labels(y_pred_df, exp_labels)

# Erstelle eine Spalte mit den tatsächlichen Experimentstypen
y_test_labels = one_hot_to_labels(y_test_df, exp_labels)

# Berechnung der Accuracy
overall_accuracy = (y_pred_labels == y_test_labels).mean()
print(f"Overall Accuracy: {overall_accuracy:.4f}")

mask = [pred is not None and pred != "" for pred in y_pred_labels]

# Nur gültige Einträge auswählen
valid_y_pred = np.array(y_pred_labels)[mask]
valid_y_test = np.array(y_test_labels)[mask]

# Accuracy berechnen
overall_accuracy = (valid_y_pred == valid_y_test).mean()
print(overall_accuracy)
print(sum(mask), len(mask))
# Out:
# 23
# (364, 5645)
# Classification Report for Experiment Type_ Affinity purification coupled with mass spectrometry proteomics:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98        90
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.97        91
#    macro avg       0.49      0.49      0.49        91
# weighted avg       0.98      0.97      0.97        91
#
# Classification Report for Experiment Type_ All-ion fragmentation:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        91
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.99        91
#    macro avg       0.50      0.49      0.50        91
# weighted avg       1.00      0.99      0.99        91
#
# Classification Report for Experiment Type_ Bottom-up proteomics:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        91
#
#     accuracy                           1.00        91
#    macro avg       1.00      1.00      1.00        91
# weighted avg       1.00      1.00      1.00        91
#
# Classification Report for Experiment Type_ Chemical cross-linking coupled with mass spectrometry proteomics:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        90
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        91
#    macro avg       0.49      0.50      0.50        91
# weighted avg       0.98      0.99      0.98        91
#
# Classification Report for Experiment Type_ Data-dependent acquisition:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98        89
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.97        91
#    macro avg       0.49      0.49      0.49        91
# weighted avg       0.96      0.97      0.96        91
#
# Classification Report for Experiment Type_ Data-independent acquisition:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        90
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        91
#    macro avg       0.49      0.50      0.50        91
# weighted avg       0.98      0.99      0.98        91
#
# Classification Report for Experiment Type_ Gel-based experiment:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        91
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.98        91
#    macro avg       0.50      0.49      0.49        91
# weighted avg       1.00      0.98      0.99        91
#
# Classification Report for Experiment Type_ HDMSE:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        89
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.98        91
#    macro avg       0.49      0.50      0.49        91
# weighted avg       0.96      0.98      0.97        91
#
# Classification Report for Experiment Type_ Shotgun proteomics:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        91
#
#     accuracy                           1.00        91
#    macro avg       1.00      1.00      1.00        91
# weighted avg       1.00      1.00      1.00        91
#
# Classification Report for Experiment Type_ Top-down proteomics:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        91
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.98        91
#    macro avg       0.50      0.49      0.49        91
# weighted avg       1.00      0.98      0.99        91
#
# Classification Report for Experiment Type_Affinity proteomics:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        89
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.98        91
#    macro avg       0.49      0.50      0.49        91
# weighted avg       0.96      0.98      0.97        91
#
# Classification Report for Experiment Type_Affinity purification coupled with mass spectrometry proteomics:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        87
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.96        91
#    macro avg       0.48      0.50      0.49        91
# weighted avg       0.91      0.96      0.93        91
#
# Classification Report for Experiment Type_Bottom-up proteomics:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        83
#            1       1.00      0.12      0.22         8
#
#     accuracy                           0.92        91
#    macro avg       0.96      0.56      0.59        91
# weighted avg       0.93      0.92      0.89        91
#
# Classification Report for Experiment Type_Chemical cross-linking coupled with mass spectrometry proteomics:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        91
#
#     accuracy                           1.00        91
#    macro avg       1.00      1.00      1.00        91
# weighted avg       1.00      1.00      1.00        91
#
# Classification Report for Experiment Type_Data-dependent acquisition:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        91
#
#     accuracy                           1.00        91
#    macro avg       1.00      1.00      1.00        91
# weighted avg       1.00      1.00      1.00        91
#
# Classification Report for Experiment Type_Gel-based experiment:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98        88
#            1       0.50      0.33      0.40         3
#
#     accuracy                           0.97        91
#    macro avg       0.74      0.66      0.69        91
# weighted avg       0.96      0.97      0.96        91
#
# Classification Report for Experiment Type_HDMSE:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        91
#
#     accuracy                           1.00        91
#    macro avg       1.00      1.00      1.00        91
# weighted avg       1.00      1.00      1.00        91
#
# Classification Report for Experiment Type_RNA mass spectrometry:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        91
#
#     accuracy                           1.00        91
#    macro avg       1.00      1.00      1.00        91
# weighted avg       1.00      1.00      1.00        91
#
# Classification Report for Experiment Type_SRM/MRM:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        90
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        91
#    macro avg       0.49      0.50      0.50        91
# weighted avg       0.98      0.99      0.98        91
#
# Classification Report for Experiment Type_SWATH MS:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        91
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.99        91
#    macro avg       0.50      0.49      0.50        91
# weighted avg       1.00      0.99      0.99        91
#
# Classification Report for Experiment Type_Shotgun proteomics:
#               precision    recall  f1-score   support
#
#            0       0.44      0.55      0.49        29
#            1       0.76      0.68      0.72        62
#
#     accuracy                           0.64        91
#    macro avg       0.60      0.61      0.61        91
# weighted avg       0.66      0.64      0.65        91
#
# Classification Report for Experiment Type_Top-down proteomics:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97        87
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.95        91
#    macro avg       0.48      0.49      0.49        91
# weighted avg       0.91      0.95      0.93        91
#
# Classification Report for Experiment Type_mass spectrometry imaging:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        91
#
#     accuracy                           1.00        91
#    macro avg       1.00      1.00      1.00        91
# weighted avg       1.00      1.00      1.00        91
#
# Overall Accuracy: 0.4835
# 0.6470588235294118
# 68 91

# %%
(0.575 * 23 + 0.64705 * 68)/ 91
# Out:
# 0.6288395604395605
